# %%
from pytube import YouTube
import requests
import json
import re

# %%
# youube data api v3
def get_youtube_search(query):
    assert type(query) is str
    url = 'https://www.googleapis.com/youtube/v3/search?part=id&maxResults=10&q='+query+'&relevanceLanguage=ko&key=AIzaSyALf1tdgaDLvyplfblk-q6lQQvuT6DIoXE'
    res = requests.get(url)
    r = json.loads(res.text)

    video_ids = []
    for i in r['items']:
        try:
            video_ids.append(i['id']['videoId'])
        except: pass
    
    if res.status_code == 200 and len(video_ids)>0:
        return video_ids
    else: return []

# %%
vids = get_youtube_search('세글자')

# %%
vids
# Out:
# ['mzx0AkN6Ezs',
#  'FY_SEvFdHng',
#  'Xm1VLKlWHyI',
#  '4SMYvTlUXVk',
#  'ceNWRzt9XnI',
#  'bh4KQbPS704',
#  'CK2MFrZ4XdQ',
#  'ry9kvJ9sm4g',
#  'iGebdzBEEsY']

# %%
# youube data api v3
def compare_duration(vid):
    assert type(vid) is str
    url = 'https://www.googleapis.com/youtube/v3/videos?key=AIzaSyALf1tdgaDLvyplfblk-q6lQQvuT6DIoXE'
    url += '&part=contentDetails&id='+vid
    res = requests.get(url)
    r = json.loads(res.text)
    
    dur = r['items'][0]['contentDetails']['duration']
    try:
        dur.index('H')
        print('too long')
        return False # 1시간 이상은 무조건 자름
    except: pass
    dur_ = dur[2:]
    if dur_.find('M')>-1: m = int(dur_[:dur_.index('M')])
    else: m=0
    if dur_.find('S')>-1: s = int(dur_[dur_.index('M')+1:dur_.index('S')])
    else: s=0
    dur = m*60 + s
    print('vid:', vid, ', duration:', dur)
    
    dur_min = 180
    dur_max = 300
    if res.status_code == 200 and dur>dur_min and dur<dur_max:
        return True
    else:
        print('too long')
        return False

# %%
for v in vids:
    if compare_duration(v):
        download_audio(v)
        break
# Out:
# too long
# vid: x7WFLkshZrQ , duration: 3545
# too long
# vid: NM57btQOZsY , duration: 3455
# too long
# too long
# too long

# %%
[compare_duration(i) for i in vids]
# Out:
# vid: mzx0AkN6Ezs , duration: 605
# too long
# too long
# vid: Xm1VLKlWHyI , duration: 656
# too long
# too long
# too long
# too long
# vid: CK2MFrZ4XdQ , duration: 233
# vid: ry9kvJ9sm4g , duration: 703
# too long
# too long
# [False, False, False, False, False, False, True, False, False]

# %%
a = None
# a='alal'
if not a: print('appe')
# Out:
# appe

# %%
# DOWNLOAD AUDIO FILE
# https://python-pytube.readthedocs.io/en/latest/user/quickstart.html
def download_audio(video_id):
    assert type(video_id) is str
    url = 'https://www.youtube.com/watch?v='+video_id
    yt = YouTube(url)
    
    print(yt.title)
    
    # itag 249,250,251만 시용
    r = yt.streams.get_by_itag(249)
    if not r: # 249 itag 없음
        r = yt.streams.get_by_itag(250)
        if not r: # 250 itag 없음
            r = yt.streams.get_by_itag(251)
            if not r: # 251 itag 없음
                r = yt.streams.get_by_itag(140) #.mp4
                if not r: return 'Sorry, no audio stream'
            
    r.download('./static/audio')
    reg = re.compile('[\/:*?"<>|,.]') # 저장시에 파일이름에 못들어가는 특수문자 보정 
    title = reg.sub('', yt.title)
    return title+'.webm'

# %%
vid = get_youtube_search('러블리즈 노래 아츄')
print(vid)
if len(vid)>0:
    audio = download_audio(vid[0])
# Out:
# ['Y4Ai77YL99o', 'T7w33eSs-SY', 'DEd8ED2FdAg', 'VqJGeBzTqtE', 'JladDWXgIEM']
# Lovelyz 러블리즈 - Ah-Choo 아츄 Lyrics [ Romanization / Hangul / Translation ]

# %%
url = 'https://www.youtube.com/watch?v='+vid[0]
yt = YouTube(url)

# %%
yt.streams.all()
# Out:
# [<Stream: itag="43" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp8.0" acodec="vorbis">,
#  <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2">,
#  <Stream: itag="36" mime_type="video/3gpp" res="240p" fps="30fps" vcodec="mp4v.20.3" acodec="mp4a.40.2">,
#  <Stream: itag="17" mime_type="video/3gpp" res="144p" fps="30fps" vcodec="mp4v.20.3" acodec="mp4a.40.2">,
#  <Stream: itag="135" mime_type="video/mp4" res="480p" fps="30fps" vcodec="avc1.4d401e">,
#  <Stream: itag="244" mime_type="video/webm" res="480p" fps="30fps" vcodec="vp9">,
#  <Stream: itag="134" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.4d401e">,
#  <Stream: itag="243" mime_type="video/webm" res="360p" fps="30fps" vcodec="vp9">,
#  <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d400d">,
#  <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9">,
#  <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c">,
#  <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9">,
#  <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2">,
#  <Stream: itag="171" mime_type="audio/webm" abr="128kbps" acodec="vorbis">,
#  <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus">,
#  <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus">,
#  <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus">]

# %% [markdown]
# ---
# ## 네이버 음성합성 api

# %%
# 네이버 음성합성 Open API 예제
import os
import sys
import urllib.request

# %%
client_id = "kwjiwaqr0b"
client_secret = "PU5Ewecvdnch7gUHg6x38zILYXkjvPssCGOVwJuz"
# encText = urllib.parse.quote('이거 아닌가? 잠시만 기다려 주세요')
encText = '초코우유 너무너무 맛있다.'

data = "speaker=mijin&speed=0&text=" + encText;
url = "https://naveropenapi.apigw.ntruss.com/voice/v1/tts"
request = urllib.request.Request(url)
request.add_header("X-NCP-APIGW-API-KEY-ID",client_id)
request.add_header("X-NCP-APIGW-API-KEY",client_secret)
response = urllib.request.urlopen(request, data=data.encode('utf-8'))
rescode = response.getcode()

if(rescode==200):
    print("TTS mp3 저장")
    response_body = response.read()
    with open('1112.mp3', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)

# %%
import requests, json

# %%
client_id = "kwjiwaqr0b"
client_secret = "PU5Ewecvdnch7gUHg6x38zILYXkjvPssCGOVwJuz"
# encText = urllib.parse.quote('이거 아닌가? 잠시만 기다려 주세요')
text = '초코우유 너무너무 맛있다.'

url = "https://naveropenapi.apigw.ntruss.com/voice/v1/tts"#?speaker=mijin&speed=0&text="
# url = url+text
headers = {
      'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
      'X-NCP-APIGW-API-KEY-ID': 'kwjiwaqr0b',
      'X-NCP-APIGW-API-KEY': 'PU5Ewecvdnch7gUHg6x38zILYXkjvPssCGOVwJuz',
    }
payloads = {
    'speaker': 'mijin',
    'speed': 0,
    'text': text,
  }

# res = requests.get(url, headers=headers)
res = requests.post(url, data=payloads, headers=headers)

if(rescode==200):
    print("TTS mp3 저장")
    response_body = res.text.encode('utf-8')
    with open('1111.mp3', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# TTS mp3 저장

# %%
res.text.encode('utf-8')
# Out:
# b'ID3\x03\x00\x00\x00\x00\x00\x1aTSSE\x00\x00\x00\x10\x00\x00\x00nVoiceTTS@NAVER\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\x00\x00\x00\x00\x00\x00\x00\x00\x00Info\x00\x00\x00\x0f\x00\x00\x00B\x00\x00K`\x00\x03\x07\x07\x0b\x0f\x0f\x13\x17\x17\x1b\x1f\x1f"&&*..266:>>AEEIMMQUUY]]`ddhllpttx||9nVoiceTTS\x01P\x00\x00\x00\x00\x00\x00\x00\x00\x14@$\x00\x00"\x00\x00@\x00\x00K` \x0b\xef\xbf\xbdkH\x01@\x00\x00nVoiceTTS@NAVERUUUUU\xef\xbf\xbd\xef\xbf\xbd\x0c\xef\xbf\xbd66\x02\xef\xbf\xbd\xef\xbf\xbd=\xef\xbf\xbdx\x14b\xef\xbf\xbdo\xef\xbf\xbdV\rR\xef\xbf\xbd<#\xef\xbf\xbd\xef\xbf\xbdp?$\x10\x0c\xef\xbf\xbd\xef\xbf\xbd\x03L\xef\xbf\xbd}\xef\xbf\xbd\xef\xbf\xbd\x06\xef\xbf\xbd4\xef\xbf\xbd\x03 \x19\xef\xbf\xbdh\x06\xef\xbf\xbd?}n\xea\x81\x87\xef\xbf\xbd\xef\xbf\xbdhQ\xef\xbf\xbd\x1a\xdc\xb2\x06$:\x01\xef\xbf\xbd\x04\xdf\xb3\xef\xbf\xbd\x1a\xef\xbf\xbdh\x06C&\xef\xbf\xbd \xef\xbf\xbd\x16\x0b\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\x00\x0c,\xef\xbf\xbd\xef\xbf\xbd\x0c\xef\xbf\xbd\x0e\x03\x07\xef\xbf\xbd\xef\xbf\xbd\x08~\x06?\x07\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd@\x1c,\x03#\x05\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd0X\xef\xbf\xbd\x00\xef\xbf\xbd`f0\xef\xbf\xbd\x18pH\x19\xef\xbf\xbd1` \x0c\x16/\x03\x16\xef\xbf\xbd@\xc6\xa0\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd\xef\xbf\xbd0\x10x\x00\xef\xbf\xbd\xef\xbf\xbdd\xef\xbf\xbd\xef\xbf\xbd\x18\\Z\x01\xef\xbf\xbd
5\x13\x17c\x9e\x02\x0e0U\x14h\xbe\xba\x01\xc4\x16\x02_k\x96\x95%T\xe8\xbe\x0c\x94X\xe1\xc0E\r/\x1bX\x1d\x1c\x94\x94\xff\xf3\x88\xc4\xf3h\x94\x16\x00\x01\x9b\xc8\x00\x12\xa90\x80@E)p)\xc0\xe1\x89\x0e\x15\x05}$S-f\xfbbn\x18\xc0(V]\xb6t\x1c\x02\t\n\xa2&\x10\x88F\x12\xc5Ws\x10D\x91\x01,\xa9\xb5e\x88\x8d>\r\x08iU6.j\xa9;DA\x97\x9c\x84\x17\\T8\xca#\xac(a\xc0h^\x14eQ\xe4\x92\x10\x8e\x9e`#\xd8\xba\xc46A\n ,\xa21\x1b\xd3$\x88q\xe9\xca\x1cZ*8\xa9\xd6\xa2\xa9\x10\x98\x02\x85\x96\x03@R3\x8d\x08 52\xd1\x150C\x13\x10\x14\x00\x19\xa7\x88\x82m\x94\x8a2O\xa3*\x8e\xa4\xcb\x90\xcb\xc1\xcd\x98#<\xacX(`\xa2\xc3\x85,\ne\x18\x82\xcc\xca\x15\t}\x15\x887\x83\x86)\x84w\x18r\xdd\\\x1d\x05\x0c\x84ba\x99\x8a\x08Rpbz\xb7\xc9\xf6B\x80\xe02\x04ylKP2BdL\xa5\x13_\x8e?\x83\xbde\xc9\xd6\xa9\xd4\xd5\x9f[\x98\x9cy\x14\xad\x04\xc8\xd2L\x8c\xb6\x1ax\xe7\xdd\xf8\xbc\x0c\xf6\xbb\xea\xe4Y0\x16AAA\x052W*\n{\x9d\x97~\x82\x1cu&\xe7\xd0\x08\xff\xf3\x88\xc4cU\xcc\x16\x8f\x1f\x98\xc8\x00\xb1\x84"\x97\xbc8E\x8d\x19\x90\xc4\xa6#Q\xd9|\xc4\xb2\x11/\xe4\xc3(Xdy\x02\x06\x04 \xb4\xe3\x04n\x93\x1aGu\xf8\xed\x9br\xfdX\x96P\xc5\xder\xf6\xa7c\x90\xa6\xccED\x89\xa1!\x189\xa9\xfa\x90<\xc7S\xad\xa5\xac (zNcZ)\x14\xaf\xdb\xf8\x7f\xa3\xfa\xf4\x04\x9a*\xe0\xf4(\x9b\xefr24\xdbI\x00\x88\x84M\x13\x14\x0bl\x8b\xd3\x08\xc6\x86\xa1\x01\x93\xa2\xabEZ\xb4t\x90\xe5\xdbr\xfb\x93\x93\x95\xf0\xcfV"\x92*\xe0\xa0\xd2\xfd\x7f\xcb%\xf2\xb9M\xbbsr9[ ...

# %% [markdown]
# ---
# ## youtube-dl download

# %%
import subprocess

def download_audio_sub_process(video_id, file_name, ext='mp3'):
    assert type(video_id) is str and type(file_name) is str
    assert file_name.find(' ')==-1, 'file_name should have no spacebar(" ")'
    
    command = 'youtube-dl https://www.youtube.com/watch?v={} -x --audio-format {} --output ./static/audio/{}.%(ext)s'.format(video_id, ext, file_name)
    print(command)
    subprocess.call(command, shell=True)
    return file_name+'.'+ext

# %%
download_audio_sub_process('jeqdYqsrsA0', '좋은날')
# Out:
# youtube-dl https://www.youtube.com/watch?v=jeqdYqsrsA0 -x --audio-format mp3 --output ./static/audio/좋은날.%(ext)s
# '좋은날.mp3'
